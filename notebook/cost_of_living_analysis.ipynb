# %% [markdown]
# # Cost of Living Pulse (2023-2024)
#
# Monthly prices for everyday essentials in Sri Lanka.
#
# **Goal:** show which items rose fastest.

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
ROOT = Path("..").resolve()
DATA = ROOT / "data" / "cost_of_living_sri_lanka.csv"
CHARTS = ROOT / "charts"
CHARTS.mkdir(exist_ok=True)
BASELINE = pd.Timestamp("2023-01-01")

# %%
df = pd.read_csv(DATA)
df["date"] = pd.to_datetime(df["year"].astype(str) + "-" + df["month"].astype(str) + "-01")
df.head()

# %%
print("Categories:", df["category"].nunique())
print("Date range:", df["date"].min().date(), "to", df["date"].max().date())
df.groupby("category")["price_lkr"].agg(["min","max","mean"]).round(2)

# %% [markdown]
# ## Price trends by category

# %%
plt.figure(figsize=(11, 6))
for category, group in df.groupby("category"):
    s = group.sort_values("date")
    plt.plot(s["date"], s["price_lkr"], marker="o", linewidth=1.8, label=category)
plt.title("Essential Prices in Sri Lanka (2023-2024)")
plt.xlabel("Month"); plt.ylabel("Price (LKR)")
plt.legend(loc="upper left", fontsize=8); plt.grid(True, alpha=0.3)
plt.tight_layout(); plt.savefig(CHARTS / "price_trends.png", dpi=150); plt.show()

# %% [markdown]
# ## Percent change from Jan 2023

# %%
baseline = df[df["date"] == BASELINE].set_index("category")["price_lkr"]
latest_date = df["date"].max()
latest = df[df["date"] == latest_date].set_index("category")["price_lkr"]
pct = ((latest - baseline) / baseline * 100).sort_values(ascending=False)
plt.figure(figsize=(8, 5)); pct.plot(kind="bar", color="#2980b9")
plt.title(f"Price Rise Since Jan 2023 (to {latest_date.strftime('%b %Y')})")
plt.xlabel("Category"); plt.ylabel("Percent change (%)")
plt.xticks(rotation=30, ha="right"); plt.tight_layout()
plt.savefig(CHARTS / "pct_change_baseline.png", dpi=150); plt.show()
print("Fastest-rising:", pct.idxmax(), f"({pct.max():.1f}%)")

# %% [markdown]
# ## Conclusions
#
# 1. Fuel and electricity spike when tariffs change.
# 2. Food staples rise steadily.
# 3. Bus fares increase in steps.
#
# *Synthetic data for learning.*
